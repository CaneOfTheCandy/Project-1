# %% [markdown]
# # UNMC Air Quality Q & A:

# %% [markdown]
# ### 1. What are the 5 locations in Nebraska with the highest mean and median concentrations of VOC, PM 2.5 and PM 10.0?

# %%
import pandas as pd
air_data = pd.read_csv('AirQuality_Daily_StudentVersion.csv') 
air_data = pd.DataFrame(air_data)

PM2_5 = air_data.groupby(['sensor.name']).agg(mean = ('pm2.5_atm', 'mean'),
                                                     median = ('pm2.5_atm', 'median')).sort_values(['mean', 'median'], ascending=False).head(5)

VOC = air_data.groupby(['sensor.name']).agg(mean = ('voc', 'mean'),
                                                     median = ('voc', 'median')).sort_values(['mean', 'median'], ascending=False).head(5)

PM10 = air_data.groupby(['sensor.name']).agg(mean = ('pm10.0_atm', 'mean'),
                                                     median = ('pm10.0_atm', 'median')).sort_values(['mean', 'median'], ascending=False).head(5)
print("Top 5 Locations for PM2.5:")
print(PM2_5, "\n")

print("Top 5 Locations for PM10:")
print(PM10, "\n")

print("Top 5 Locations for VOC:")
print(VOC)
# Out:
# Top 5 Locations for PM2.5:
#                                                           mean     median
# sensor.name
# Broken Bow                                          928.710593  36.050240
# #16 - Richardson County Courthouse                  700.127342  11.977344
# #18 - Southeast District Health Department- Tec...  613.175352  10.322875
# NCDHD O'Neill #11                                   164.495078   7.251208
# Swnphd-mccook                                       123.011622   4.582281
#
# Top 5 Locations for PM10:
#                                                           mean     median
# sensor.name
# Broken Bow                                          929.678512  43.179094
# #16 - Richardson County Courthouse                  701.632446  13.305615
# #18 - Southeast District Health Department- Tec...  614.227248  11.433729
# NCDHD O'Neill #11                                   166.132578   8.427437
# Swnphd-mccook                                       124.227336   5.372073
#
# Top 5 Locations for VOC:
#                                              mean      median
# sensor.name
# Swnphd-ogallala                        399.434240  423.082292
# FCHD-YPS                               372.462720  375.383500
# Three Rivers Public Health Department  370.216208  376.810167
# ELVPHD Norfolk HD 4                    360.833744  368.580500
# Swnphd-mccook                          353.941581  381.468479

# %% [markdown]
# ### 2. On what days did the maximum values occur and where did this maximums occur?

# %%
PM2_5max = air_data.loc[air_data['pm2.5_atm'].idxmax()] 
PM10_max = air_data.loc[air_data['pm10.0_atm'].idxmax()]
VOC_max  = air_data.loc[air_data['voc'].idxmax()]

summary = pd.DataFrame({
    'Pollutant': ['PM2.5', 'PM10', 'VOC'],
    'Max Value': [PM2_5max['pm2.5_atm'], PM10_max['pm10.0_atm'], VOC_max['voc']],
    'Date': [PM2_5max['date'], PM10_max['date'], VOC_max['date']],
    'Sensor Name & Location': [PM2_5max['sensor.name'], PM10_max['sensor.name'], VOC_max['sensor.name']]
})

print(summary)
# Out:
#   Pollutant    Max Value      Date              Sensor Name & Location
# 0     PM2.5  3782.823313  02/18/25  #16 - Richardson County Courthouse
# 1      PM10  3784.682542  02/18/25  #16 - Richardson County Courthouse
# 2       VOC  1209.931571  06/24/24                     Swnphd-ogallala

# %% [markdown]
# ### 3. Does humidity and temperature have a noticeable effect on air quality?

# %%
def categorize_humidity(humidity):
    if humidity < 50:
        return 'Low'
    elif humidity <= 80:
        return 'High'
    else:
        return 'Very High'

def categorize_temperature(temperature):
    if temperature < 32:
        return 'Below Freezing'
    elif temperature <= 50:
        return 'Cool'
    elif temperature <= 70:
        return 'Warm'
    else:
        return 'Hot'

air_data['Humidity Category'] = air_data['humidity'].apply(categorize_humidity)
air_data['Temperature Category'] = air_data['temperature'].apply(categorize_temperature)

correlation = air_data[['pm2.5_atm', 'pm10.0_atm', 'voc', 'humidity', 'temperature']].corr()

print("\n Average Correlation Between Pollutants, Humidity, and Temperature:")
print(correlation)

for sensor, group in air_data.groupby('sensor.name'):
    print(f"\nCorrelation for sensor: {sensor}")
    corr = group[['pm2.5_atm', 'pm10.0_atm', 'voc', 'humidity', 'temperature']].corr()
    print(corr)
# Out:
#  Average Correlation Between Pollutants, Humidity, and Temperature:
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.999990 -0.012408 -0.008327    -0.197996
# pm10.0_atm    0.999990    1.000000 -0.011899 -0.008054    -0.198141
# voc          -0.012408   -0.011899  1.000000 -0.067082     0.035466
# humidity     -0.008327   -0.008054 -0.067082  1.000000    -0.012772
# temperature  -0.197996   -0.198141  0.035466 -0.012772     1.000000
#
# Correlation for sensor: #16 - Richardson County Courthouse
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.999999  0.018535  0.016993     0.148728
# pm10.0_atm    0.999999    1.000000  0.020175  0.016432     0.148801
# voc           0.018535    0.020175  1.000000 -0.495272     0.058156
# humidity      0.016993    0.016432 -0.495272  1.000000    -0.109179
# temperature   0.148728    0.148801  0.058156 -0.109179     1.000000
#
# Correlation for sensor: #17 - Otoe County
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.994011  0.024555  0.378610     0.004088
# pm10.0_atm    0.994011    1.000000  0.058050  0.342214    -0.024000
# voc           0.024555    0.058050  1.000000 -0.184691    -0.492492
# humidity      0.378610    0.342214 -0.184691  1.000000     0.191302
# temperature   0.004088   -0.024000 -0.492492  0.191302     1.000000
#
# Correlation for sensor: #18 - Southeast District Health Department- Tecumseh
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.999999  0.755548 -0.149102    -0.840050
# pm10.0_atm    0.999999    1.000000  0.755540 -0.148947    -0.840037
# voc           0.755548    0.755540  1.000000 -0.062687    -0.469479
# humidity     -0.149102   -0.148947 -0.062687  1.000000     0.096412
# temperature  -0.840050   -0.840037 -0.469479  0.096412     1.000000
#
# Correlation for sensor: Ainsworth Public School #9
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.995675  0.209522  0.192696    -0.140541
# pm10.0_atm    0.995675    1.000000  0.216351  0.165664    -0.183898
# voc           0.209522    0.216351  1.000000 -0.020458    -0.059093
# humidity      0.192696    0.165664 -0.020458  1.000000    -0.084763
# temperature  -0.140541   -0.183898 -0.059093 -0.084763     1.000000
#
# Correlation for sensor: Broken Bow
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.999999  0.647803 -0.263987    -0.764981
# pm10.0_atm    0.999999    1.000000  0.647863 -0.264100    -0.764794
# voc           0.647803    0.647863  1.000000 -0.458462    -0.291295
# humidity     -0.263987   -0.264100 -0.458462  1.000000    -0.048234
# temperature  -0.764981   -0.764794 -0.291295 -0.048234     1.000000
#
# Correlation for sensor: Buffalo County TRPHD #26
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.989602  0.190618  0.251023     0.186203
# pm10.0_atm    0.989602    1.000000  0.198418  0.233005     0.180092
# voc           0.190618    0.198418  1.000000  0.054326     0.045616
# humidity      0.251023    0.233005  0.054326  1.000000    -0.037062
# temperature   0.186203    0.180092  0.045616 -0.037062     1.000000
#
# Correlation for sensor: ELVPHD Norfolk HD 4
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.977101  0.171796  0.131255     0.150799
# pm10.0_atm    0.977101    1.000000  0.191231  0.131855     0.112412
# voc           0.171796    0.191231  1.000000 -0.057606     0.605092
# humidity      0.131255    0.131855 -0.057606  1.000000    -0.309226
# temperature   0.150799    0.112412  0.605092 -0.309226     1.000000
#
# Correlation for sensor: ELVPHD Tekamah HD 3
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.997064  0.113027  0.323454     0.207908
# pm10.0_atm    0.997064    1.000000  0.111331  0.297621     0.186437
# voc           0.113027    0.111331  1.000000  0.025416     0.395785
# humidity      0.323454    0.297621  0.025416  1.000000     0.049525
# temperature   0.207908    0.186437  0.395785  0.049525     1.000000
#
# Correlation for sensor: ELVPHD Wisner HD 5
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.963204  0.105411 -0.108376     0.353042
# pm10.0_atm    0.963204    1.000000  0.105458 -0.116461     0.322884
# voc           0.105411    0.105458  1.000000 -0.543680    -0.047240
# humidity     -0.108376   -0.116461 -0.543680  1.000000     0.018868
# temperature   0.353042    0.322884 -0.047240  0.018868     1.000000
#
# Correlation for sensor: FCHD-YPS
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.995681  0.085655  0.136009     0.134395
# pm10.0_atm    0.995681    1.000000  0.091916  0.144939     0.114400
# voc           0.085655    0.091916  1.000000  0.415811     0.301309
# humidity      0.136009    0.144939  0.415811  1.000000     0.156040
# temperature   0.134395    0.114400  0.301309  0.156040     1.000000
#
# Correlation for sensor: Laurel High School
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.992027  0.170297  0.270886     0.235364
# pm10.0_atm    0.992027    1.000000  0.185391  0.202446     0.223798
# voc           0.170297    0.185391  1.000000 -0.061777     0.521733
# humidity      0.270886    0.202446 -0.061777  1.000000    -0.035390
# temperature   0.235364    0.223798  0.521733 -0.035390     1.000000
#
# Correlation for sensor: Loup Basin Public Health Department
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.993444  0.118248  0.090728     0.186375
# pm10.0_atm    0.993444    1.000000  0.113287  0.078790     0.171988
# voc           0.118248    0.113287  1.000000  0.135506     0.495456
# humidity      0.090728    0.078790  0.135506  1.000000     0.001357
# temperature   0.186375    0.171988  0.495456  0.001357     1.000000
#
# Correlation for sensor: Lower Niobrara NRD Butte 10
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.992584 -0.027650  0.154762     0.104263
# pm10.0_atm    0.992584    1.000000 -0.000638  0.126453     0.031655
# voc          -0.027650   -0.000638  1.000000 -0.191437    -0.370123
# humidity      0.154762    0.126453 -0.191437  1.000000    -0.113155
# temperature   0.104263    0.031655 -0.370123 -0.113155     1.000000
#
# Correlation for sensor: NCDHD O'Neill #11
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.999992  0.128913 -0.225735    -0.240850
# pm10.0_atm    0.999992    1.000000  0.130021 -0.225437    -0.240042
# voc           0.128913    0.130021  1.000000  0.101162     0.570682
# humidity     -0.225735   -0.225437  0.101162  1.000000    -0.086964
# temperature  -0.240850   -0.240042  0.570682 -0.086964     1.000000
#
# Correlation for sensor: PHS Fairbury JCHL 13
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.994028  0.184916  0.148373     0.002393
# pm10.0_atm    0.994028    1.000000  0.168453  0.132130    -0.041409
# voc           0.184916    0.168453  1.000000 -0.115581     0.041927
# humidity      0.148373    0.132130 -0.115581  1.000000     0.042923
# temperature   0.002393   -0.041409  0.041927  0.042923     1.000000
#
# Correlation for sensor: SWNPHD-Imerial
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.997065  0.161342  0.133704     0.223576
# pm10.0_atm    0.997065    1.000000  0.165499  0.109758     0.224417
# voc           0.161342    0.165499  1.000000 -0.069778     0.094809
# humidity      0.133704    0.109758 -0.069778  1.000000    -0.321446
# temperature   0.223576    0.224417  0.094809 -0.321446     1.000000
#
# Correlation for sensor: South Heartland District Health Dept. Hastings office
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.996813  0.101951  0.352604     0.117111
# pm10.0_atm    0.996813    1.000000  0.098732  0.324501     0.102674
# voc           0.101951    0.098732  1.000000  0.070156     0.103876
# humidity      0.352604    0.324501  0.070156  1.000000     0.066661
# temperature   0.117111    0.102674  0.103876  0.066661     1.000000
#
# Correlation for sensor: South Heartland District Health Dept. Superior City Building
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.996128  0.004656  0.366618     0.061777
# pm10.0_atm    0.996128    1.000000  0.014262  0.338902     0.040114
# voc           0.004656    0.014262  1.000000 -0.028498    -0.366304
# humidity      0.366618    0.338902 -0.028498  1.000000     0.026117
# temperature   0.061777    0.040114 -0.366304  0.026117     1.000000
#
# Correlation for sensor: Swnphd-Benklemen
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.994012  0.188364  0.161885     0.193219
# pm10.0_atm    0.994012    1.000000  0.205827  0.145215     0.204242
# voc           0.188364    0.205827  1.000000  0.084265     0.325774
# humidity      0.161885    0.145215  0.084265  1.000000    -0.153112
# temperature   0.193219    0.204242  0.325774 -0.153112     1.000000
#
# Correlation for sensor: Swnphd-mccook
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.999996 -0.112183 -0.054763    -0.426834
# pm10.0_atm    0.999996    1.000000 -0.112044 -0.054718    -0.426558
# voc          -0.112183   -0.112044  1.000000  0.161417     0.343046
# humidity     -0.054763   -0.054718  0.161417  1.000000     0.034045
# temperature  -0.426834   -0.426558  0.343046  0.034045     1.000000
#
# Correlation for sensor: Swnphd-ogallala
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.999810  0.007211 -0.034406     0.097724
# pm10.0_atm    0.999810    1.000000  0.008954 -0.035892     0.101445
# voc           0.007211    0.008954  1.000000  0.015203     0.280197
# humidity     -0.034406   -0.035892  0.015203  1.000000    -0.202451
# temperature   0.097724    0.101445  0.280197 -0.202451     1.000000
#
# Correlation for sensor: TRPHD Dawson Co. Courthouse 25
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.999913  0.021524  0.032462    -0.196663
# pm10.0_atm    0.999913    1.000000  0.024489  0.034502    -0.197152
# voc           0.021524    0.024489  1.000000  0.222181     0.186877
# humidity      0.032462    0.034502  0.222181  1.000000    -0.044793
# temperature  -0.196663   -0.197152  0.186877 -0.044793     1.000000
#
# Correlation for sensor: TRPHD Harlan Co. Courthouse 24
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.996577 -0.103681  0.309136     0.179577
# pm10.0_atm    0.996577    1.000000 -0.085324  0.281684     0.145746
# voc          -0.103681   -0.085324  1.000000 -0.100799    -0.433738
# humidity      0.309136    0.281684 -0.100799  1.000000     0.165559
# temperature   0.179577    0.145746 -0.433738  0.165559     1.000000
#
# Correlation for sensor: Three Rivers Public Health Department
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.993513  0.055248  0.305216     0.015169
# pm10.0_atm    0.993513    1.000000  0.042767  0.268901    -0.014038
# voc           0.055248    0.042767  1.000000  0.024456     0.504383
# humidity      0.305216    0.268901  0.024456  1.000000    -0.041922
# temperature   0.015169   -0.014038  0.504383 -0.041922     1.000000
#
# Correlation for sensor: WCDHD Arthur High School 28
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.996181 -0.072748  0.117388     0.232778
# pm10.0_atm    0.996181    1.000000 -0.055676  0.083244     0.211188
# voc          -0.072748   -0.055676  1.000000 -0.159116    -0.363502
# humidity      0.117388    0.083244 -0.159116  1.000000    -0.115520
# temperature   0.232778    0.211188 -0.363502 -0.115520     1.000000
#
# Correlation for sensor: WCDHD City Building
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.997051  0.061332  0.341759     0.105946
# pm10.0_atm    0.997051    1.000000  0.080163  0.301237     0.099961
# voc           0.061332    0.080163  1.000000 -0.151838    -0.437007
# humidity      0.341759    0.301237 -0.151838  1.000000     0.044013
# temperature   0.105946    0.099961 -0.437007  0.044013     1.000000
#
# Correlation for sensor: WCDHD Thedford Library 29
#              pm2.5_atm  pm10.0_atm       voc  humidity  temperature
# pm2.5_atm     1.000000    0.994464  0.204342  0.479186     0.209723
# pm10.0_atm    0.994464    1.000000  0.197567  0.453071     0.140037
# voc           0.204342    0.197567  1.000000  0.163611    -0.109327
# humidity      0.479186    0.453071  0.163611  1.000000     0.086254
# temperature   0.209723    0.140037 -0.109327  0.086254     1.000000

# %% [markdown]
# ### 4. Have there been any Air Quality Index (AQI) health risks (unhealthy for sensitive populations) at any of the locations in the dataset for PM 2.5 and PM 10 based on the EPA’s AQI ratings?

# %%
def calc_aqi_pm25(c):
    bp = [
        (0.0, 12.0, 0, 50),
        (12.1, 35.4, 51, 100),
        (35.5, 55.4, 101, 150),
        (55.5, 150.4, 151, 200),
        (150.5, 250.4, 201, 300),
        (250.5, 350.4, 301, 400),
        (350.5, 500.4, 401, 500)
    ]
    for low, high, aqi_low, aqi_high in bp:
        if low <= c <= high:
            return ((aqi_high - aqi_low) / (high - low)) * (c - low) + aqi_low
    return None

def calc_aqi_pm10(c):
    bp = [
        (0, 54, 0, 50),
        (55, 154, 51, 100),
        (155, 254, 101, 150),
        (255, 354, 151, 200),
        (355, 424, 201, 300),
        (425, 504, 301, 400),
        (505, 604, 401, 500)
    ]
    for low, high, aqi_low, aqi_high in bp:
        if low <= c <= high:
            return ((aqi_high - aqi_low) / (high - low)) * (c - low) + aqi_low
    return None

air_data['AQI_PM25'] = air_data['pm2.5_atm'].apply(calc_aqi_pm25)
air_data['AQI_PM10'] = air_data['pm10.0_atm'].apply(calc_aqi_pm10)

risk_rows = air_data[
    ((air_data['AQI_PM25'] >= 101) & (air_data['AQI_PM25'] <= 150)) |
    ((air_data['AQI_PM10'] >= 101) & (air_data['AQI_PM10'] <= 150))
]
if not risk_rows.empty:
    risk_rows_sorted = (
        risk_rows
        .assign(Max_AQI=risk_rows[['AQI_PM25', 'AQI_PM10']].max(axis=1))
        .sort_values(by='Max_AQI', ascending=False)
    )

    print("Rows where AQI reached 'Unhealthy for Sensitive Groups:")
    print(risk_rows_sorted[['date', 'sensor.name', 'AQI_PM25', 'AQI_PM10']])
else:
    print("No rows reached 'Unhealthy for Sensitive Groups' for PM2.5 or PM10.")
# Out:
# Rows where AQI reached 'Unhealthy for Sensitive Groups:
#           date                                        sensor.name    AQI_PM25  \
# 2144  06/14/24                Loup Basin Public Health Department  280.261875
# 6076  12/08/24                 #16 - Richardson County Courthouse  249.049561
# 2443  06/27/24                                   Swnphd-Benklemen  238.317521
# 1350  05/14/24                               PHS Fairbury JCHL 13  143.533867
# 7493  02/15/25                                 ELVPHD Wisner HD 5  141.590744
# ...        ...                                                ...         ...
# 6720  01/09/25                                  #17 - Otoe County  101.606447
# 7836  03/02/25                                      Swnphd-mccook  101.587261
# 3799  08/21/24  South Heartland District Health Dept. Hastings...  101.431469
# 3208  07/27/24                Loup Basin Public Health Department  101.072689
# 1357  05/14/24                                         Broken Bow  101.004258
#
#         AQI_PM10
# 2144  138.990849
# 6076  123.667893
# 2443  117.817146
# 1350   55.703464
# 7493   61.127337
# ...          ...
# 6720   41.521933
# 7836   34.674479
# 3799   37.905054
# 3208   41.085995
# 1357   38.267824
#
# [121 rows x 4 columns]
